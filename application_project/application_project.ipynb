# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка их к анализу</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-в-переменные" data-toc-modified-id="Загрузка-данных-в-переменные-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных в переменные</a></span></li><li><span><a href="#Переименование-столбцов" data-toc-modified-id="Переименование-столбцов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Переименование столбцов</a></span></li><li><span><a href="#Проверка-пропущеенных-значений-и-изменение-типов-данных" data-toc-modified-id="Проверка-пропущеенных-значений-и-изменение-типов-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка пропущеенных значений и изменение типов данных</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка дубликатов</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-профилей-пользователей" data-toc-modified-id="Создание-профилей-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание профилей пользователей</a></span></li><li><span><a href="#Анализ-пользователей-по-странам" data-toc-modified-id="Анализ-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ пользователей по странам</a></span></li><li><span><a href="#Анализ-пользователей-по-устройствам" data-toc-modified-id="Анализ-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ пользователей по устройствам</a></span></li><li><span><a href="#Анализ-пользователей-по-рекламным-каналам" data-toc-modified-id="Анализ-пользователей-по-рекламным-каналам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ пользователей по рекламным каналам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расчет-потраченных-средств" data-toc-modified-id="Расчет-потраченных-средств-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расчет потраченных средств</a></span></li><li><span><a href="#Привлечение-одного-покупателя---CAC" data-toc-modified-id="Привлечение-одного-покупателя---CAC-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Привлечение одного покупателя - CAC</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Проверка-гипотезы" data-toc-modified-id="Проверка-гипотезы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проверка гипотезы</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Анализ убытков приложения ProcrastinatePRO+
#
# Предмет изучения - приложение Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Задача — разобраться в причинах и помочь компании выйти в плюс.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# * лог сервера с данными об их посещениях,
# * выгрузка их покупок за этот период,
# * рекламные расходы.
#
# Предстоит изучить:
# * откуда приходят пользователи и какими устройствами они пользуются,
# * сколько стоит привлечение пользователей из различных рекламных каналов;
# * сколько денег приносит каждый клиент,
# * когда расходы на привлечение клиента окупаются,
# * какие факторы мешают привлечению клиентов.
#
# ## Загрузка данных и подготовка их к анализу
#
# ### Загрузка данных в переменные
#
# Загрузим данные о визитах, заказах и расходах в переменные. Путь к файлам:
#  -   /datasets/visits_info_short.csv.
#  -   /datasets/orders_info_short.csv.
#  -   /datasets/costs_info_short.csv.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import warnings

# отключение предупреждений об ошибках
warnings.filterwarnings('ignore')
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# выведем на экран первые 5 строк каждой таблицы
display(visits.head(5))
display(orders.head(5))
costs.head(5)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# ### Переименование столбцов
#
# Приведем название столбцов таблиц к стилю Snake case и выведем новые имена.

# %%
# приведение названия столбцов к нижнему регистру и замена пробелов на  _ 
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
# приведение названия столбцов к нижнему регистру и замена пробелов на  _ 
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
# приведение названия столбцов к нижнему регистру
costs.columns = costs.columns.str.lower()
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# ### Проверка пропущеенных значений и изменение типов данных
#
# Проверим типы данных таблиц и их размер.

# %%
for table in [visits, orders, costs]:
    print(table.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# В таблицах нет пропущенных значений.
#
# Приведем значения `session_start`, `session_end`, `event_dt`, `dt` к типу данных `datetime`. У `costs['dt']` оставим исключительно дату.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Проверка дубликатов

# %% [markdown]
# Проверим таблицы на наличие дубликатов методом `duplicated`, просуммировав значения.

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты отсутвуют.
#
# ### Вывод
#
# Мы загрузили данные и подготовили их к анализу.
#
# Описание данных:
# Таблица visits (лог сервера с информацией о посещениях сайта):
# * `user_id` — уникальный идентификатор пользователя
# * `device` — категория устройства пользователя
# * `session_start` — дата и время начала сессии
# * `session_end` — дата и время окончания сессии
# * `channel` — идентификатор рекламного источника, из которого пришел пользователь
# * `region` - страна пользователя
#
# Таблица orders (информация о заказах):
# * `user_id` — уникальный id пользователя, который сделал заказ
# * `event_dt` — дата и время покупки
# * `revenue` — выручка
#
# Таблица costs (информация о затратах на маркетинг):
# * `channel` — идентификатор рекламного источника
# * `dt` — дата
# * `costs` — затраты на этот рекламный источник в этот день
#
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Отличная работа на этом этапе - типы данных были скорректированы, названия колонок приведены в удобный для работы вид, пропуски и дубликаты проверены.
#
# </div>
#
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Функция `get_profiles()` для создания пользовательских профилей:

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Функция `get_retention()` для расчёта удержания:

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция `get_conversion()` для расчёта конверсии:

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция `get_ltv()` для расчёта LTV и ROI:

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# А также функции для визуализации этих метрик — `filter_data()`, `plot_retention()`, `plot_conversion()` и `plot_ltv_roi()`:

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Вывод
#
# В проект добавленны функции для создания профилей, расчёта удержания, конверсии, LTV и ROI из пройденных уроков курса: get_profiles(), get_retention(), get_conversion() и get_ltv(). Также фунции для графического отображения результатов.
#
# Дальнейшая работа с данными будет осуществляться с использованием этих функций.
#
#
# ## Исследовательский анализ данных
#
# ### Создание профилей пользователей
#
# Создадим профили пользоватеелй с помощью функции `get_profiles()`, передав в качестве параметров  таблиы `visits`, `orders` и `costs`. Выведем первые 10 строк полученной таблицы профилей.

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(10)
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей.

# %%
min_date = profiles['dt'].min()
max_date = profiles['dt'].max()
print(min_date, max_date)
# Out:
# 2019-05-01 2019-10-27

# %% [markdown]
# Имеем данные пользователий с привлечением от 1 мая до 27 ноября 2019 года, что и требуется в задаче данного исследования.
#
# ### Анализ пользователей по странам
#
# Выясним из каких стран приходят посетители, страны находятся в колонке `region`.
#
# Напишем функцию `profiles_by()` для построения сгруппированной таблицы по определенному столбцу (по уvолчанию по региону). В таблице рассчитаем общее количество пользователй, количество платящиъх пользователей и их процент.

# %%
def profiles_by(column=['region']):
    profiles_by_region = profiles.groupby(column).agg({'user_id': 'nunique', 'payer': 'sum'})\
            .sort_values(by='user_id', ascending=False)
    profiles_by_region['percent'] = profiles_by_region['payer'] / profiles_by_region['user_id']
    profiles_by_region.columns = ['Пользователи', 'Платящие пользователи', '% платящих']
    return profiles_by_region.style.format({'% платящих': '{:.2%}'})

profiles_by('region')
# Out:
# <style  type="text/css" >
# </style><table id="T_2efaa_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Пользователи</th>        <th class="col_heading level0 col1" >Платящие пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2efaa_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_2efaa_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_2efaa_row0_col1" class="data row0 col1" >6902</td>
#                         <td id="T_2efaa_row0_col2" class="data row0 col2" >6.90%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Пользователи приложения Procrastinate Pro+ приходят из США, Великобритании, Франции и Германии. Платящих пользователей больше всеого из США, почти 7 тысяч, из остальных стран в 10 раз меньше. Также из США и самый больший процент платящих от общего количества - 6,9%.
#
# ### Анализ пользователей по устройствам
#
# Выясним какими устройствами пользуются посетители. Данные об устройствах находятся в колонке `device`.
#
# Посчитаем общее количесвто пользователей и платящих пользователей, их процент для каждого устройства.

# %%
profiles_by('device')
# Out:
# <style  type="text/css" >
# </style><table id="T_1abcb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Пользователи</th>        <th class="col_heading level0 col1" >Платящие пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1abcb_level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_1abcb_row0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_1abcb_row0_col1" class="data row0 col1" >3382</td>
#                         <td id="T_1abcb_row0_col2" class="data row0 col2" >6.21%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Пользователи пользуются устройствами iPhonе, Android, Mac и PC для посещения приложения. Самые популярные устройства - мобильные, сначала идут iPhonе, потом Android. При этом процент платящих пользователей самы высокий у Mac и iPhone.
#
# ### Анализ пользователей по рекламным каналам
#
# Посмотрим по каким рекламным каналам шло привлечение пользователей с помощью столбца `channel`. Для получения таблицы используем функцию `profiles_by()`.

# %%
profiles_by('channel')
# Out:
# <style  type="text/css" >
# </style><table id="T_44feb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Пользователи</th>        <th class="col_heading level0 col1" >Платящие пользователи</th>        <th class="col_heading level0 col2" >% платящих</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44feb_level0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_44feb_row0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_44feb_row0_col1" class="data row0 col1" >1160</td>
#                         <td id="T_44feb_row0_col2" class="data row0 col2" >2.06%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# У приложения 11 каналов продвижения, 10 из которых рекламные и один - органические пользователи.
#
# Самым большим каналом привлечения является органический, затем FaceBoom и TipTop. При этом процент платящих пользователей выше всего у FaceBoom, AdNonSense и lambdaMediaAds (больше 10%). Органические пользователи хороши тем, что пришли сами и на них не было затрачено средств.
#
# ### Выводы
#
# Мы создали профили пользователей и провели иследовательский анализ данных, в ходе которого было выяснено:
#
# - Пользователи приложения приходят из США, Великобритании, Франции и Германии. Платящих пользователей больше всеого из США, почти 7 тысяч, также и самый большой процент платящих от общего количества - 6,9%.
# - Пользователи пользуются устройствами iPhonе, Android, Mac и PC для посещения приложения. Самые популярные устройства - мобильные iPhonе и Android. При этом процент платящих пользователей самы высокий у Mac и iPhone.
# - У приложения 10 рекламных каналов продвижения, не считая органического. Наиболее эффективные их них органика, FaceBoom, затем TipTop. При этом процент платящих пользователей выше всего у FaceBoom, AdNonSense и lambdaMediaAds (больше 10%).

# %% [markdown]
# ## Маркетинг
#
# ### Расчет потраченных средств
#
# Посчитаем сколько денег было потрачено всего, на каждый источник суммарно и по времени. Стоимость привлечения каждого пользователя находится в столбце `acquisition_cost`.

# %%
# потратили всего
profiles['acquisition_cost'].sum()
# Out:
# 105497.29999999999

# %%
# потратили с каждого источника
cost_by_channel = profiles.groupby('channel').agg({'acquisition_cost': 'sum'})\
    .sort_values(by='acquisition_cost', ascending=False)

# вывод таблицы
display(cost_by_channel)

# построение круговой диаграммы
explode = (0, 0.05, 0.1, 0.1, 0.1, 0, 0, 0, 0, 0, 0)
cost_by_channel.plot(kind='pie', subplots=True, explode=explode, 
                    figsize=(10,8), cmap='Spectral', legend=False, autopct='%.1f%%')
plt.title('Затраты на каждый источник')
plt.show()
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %% [markdown]
# Для расчета затрат по источникам от времени создадим сводную таблицу, у которой в строках будут даты, в столбцах каналы, а на пересечении сумма затрат в день.

# %%
cost_by_channel_and_date = (
    profiles
    .pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='sum')
)
cost_by_channel_and_date.plot(figsize=(14,8), grid=True)
plt.title('Затраты по каналам и датам')
plt.xlabel('Дата')
plt.ylabel('Сумма затрат')
plt.show()

# %% [markdown]
# Все данные для расчета затрат по источникам от времени содержатся в исходной таблице `costs`. Для надежности результатов построим график по иходной таблице. Также создадим сводную таблицу по данным `costs`, у которой в строках будут даты, в столбцах каналы, а на пересечении сумма затрат в день.

# %%
cost_by_channel_and_date = (
    costs
    .pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')
)
cost_by_channel_and_date.plot(figsize=(14,8), grid=True)
plt.title('Затраты по каналам и датам')
plt.xlabel('Дата')
plt.ylabel('Сумма затрат')
plt.show()

# %% [markdown]
# Самые большие затраты по рекламным каналам FaceBoom и TipTop. Они сильно выделяются на фоне остальных каналов, траты по которым распологаются ниже `50$` и колеблятся в этом пределе на протяжении всего времени.
#
# Стоимость рекламы в FaceBoom немного возрастает, но колеблется от `90` до `300$`. При этом стоимость рекламы в TipTop растет с мая по октябрь, пиковые значения больше `600$`.

# %% [markdown]
# ### Привлечение одного покупателя - CAC
#
# Рассчитаем средний CAC на одного пользователя для всего проекта. Исключим из исследования органических пользователей, для которых значение `channel` соответсвует `organic`, так как их стоимость привлечения равна нулю и исказит среднее значение.

# %%
profiles = profiles.query('channel != "organic"')
cac = profiles['acquisition_cost'].mean()
cac
# Out:
# 1.1274813239427588

# %% [markdown]
# Рассчитаем средний CAC на одного пользователя для каждого источника трафика. Для этого выполним группировку по `channel`. Для столбца `user_id` посчитаем уникальных пользователей, для `acquisition_cost` среднее значение.
#
# Также построим график динамики изменения CAC. Для этого создадим сводную таблицу, у которой в строках будут даты, в столбцах каналы, а на пересечении средняя стоимость привлечения пользователя.

# %%
cac_by_channel = (
    profiles.groupby('channel').agg({'user_id': 'nunique', 'acquisition_cost': 'mean'})
    .sort_values(by='user_id', ascending=False)
    .rename(columns={'acquisition_cost': 'Средняя стоимость привлечения', 'user_id': 'Пользователи'})
)
# вывод таблицы
display(cac_by_channel)

# построение графика динамики CAC
cac_by_channel_and_date = (
    profiles
    .pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean')
)
cac_by_channel_and_date.plot(figsize=(14,8), grid=True)
plt.title('CAC по каналам и датам')
plt.xlabel('Дата')
plt.ylabel('Сумма затрат')
plt.show()
# Out:
#                     Пользователи  Средняя стоимость привлечения
# channel
# FaceBoom                   29144                       1.113286
# TipTop                     19561                       2.799003
# OppleCreativeMedia          8605                       0.250000
# LeapBob                     8553                       0.210172
# WahooNetBanner              8553                       0.602245
# RocketSuperAds              4448                       0.412095
# MediaTornado                4364                       0.218717
# YRabbit                     4312                       0.218975
# AdNonSense                  3880                       1.008054
# lambdaMediaAds              2149                       0.724802

# %% [markdown]
# ### Вывод
#
# Для расчетов CAC были использованы профили пользователей. В среднем привлечение одного пользователя для всего проекта стоило `1.13$`.
#
# Также были произведены расчеты среднего CAC для каждого источника трафика. Самая большая стоимость привлечения пользователя у TipTop - `2.8$`, затем идут FaceBoom и AdNonSense со стоимостью чуть больше `1$`. Самые низкие CAC у каналов LeapBob, MediaTornado и YRabbit - `0.2$`.
#
# При рассмотрениии CAC в динамике становится понятно почему на рекламу TipTop приходятся самые большие траты и высокая средняя стоимость привлечения. CAC всех рекламных каналов колеблется в небольших пределах на протяжении всего времени, линии графиков горизонтальные. Тем временем у канала TipTop средняя стоимость привлечения все время растет, с осени она больше в 3.5 раза остальных, график напоминает лестницу.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей
#
# Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы. Считаем, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Органических пользователей мы исключили из анализа на предыдущем этапе.
#
# ### Анализ общей окупаемости рекламы
#
# Установим текущую дату 1 ноября 2019 года и горизонт анализа в 14 дней.
#
# Для начала оценим общую ситуацию — посмотрим на окупаемость рекламы по всем пользователям. Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14 # горизонт анализа 

# получение ltv и roi
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=[], ignore_horizon=False
)
# визуализация данных
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
# * Реклама не окупается. ROI в конце недели — чуть выше 80%;
# * CAC увеличивается, то есть рекламный бюджет растет;
# * Динамика LTV колеблется на одном уровне, несмотря на увеличение затрат;
# * Как следствие окупаемость уменьшается. Это отражено на графике динамики ROI, она убывает.
#
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.
#
# ### Анализ окупаемости рекламы с разбивкой по устройствам
#
# Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`, указав параметр устройства для группировки - поле `device`. Для скользящего среднего оставим параметр функции по умолчанию `window = 7`.

# %%
dimensions=['device']

# получение ltv и roi
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions, ignore_horizon=False
)
# визуализация данных
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вот что говорят графики:
# * Реклама плохо окупается, ROI выше 1 только для PC после 11 дня анализа;
# * Стоимость привлечения у Mac и iPhone выше остальных, но для всех устройств графики схожи, возрастают и убывают одинакого;
# * LTV стабилен, немного ниже у PC, чем у других устройств;
#
# Посчитаем и визуализируем конверсию с разбивкой по устройствам, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# коверсия по устройствам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия не очень сильно возрастает, но все же графики соответсвуют норме. Ниже конверсия у пользователей PC (но мы уже значем, что окупаемость ROI выше остальных устройств).
#
# Вызовем функции `get_retention()` и `plot_retention()`, чтобы рассчитать и отразить на графиках удержание по устройствам.

# %%
# удержание по устройствам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удеражание пользователей для всех устройств схоже.
#
# Судя по данным, аномалий в зависимости от типа устройства нет. Далее рассмотрим разбивку по странам.
#
#
# ### Анализ окупаемости рекламы с разбивкой по странам
#
# Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`, указав параметр страны для группировки - поле `region`.

# %%
dimensions=['region']

# получение ltv и roi
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions, ignore_horizon=False
)
# визуализация данных
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Из графиков можно сделать следующие выводы:
# * LVT для всех стран растет, у США показатели выше;
# * Пользователи из США единственные не окупаются, график ROI ниже единицы, когда все остальные страны растут выше 1.5;
# * Возможно неокупаемость связана с огромными затратами на рекламу пользователей США, график динамики стоимости привлечения сильно выше остальных стран;
#
# Мы выявили проблему - пользователи из США не окупаются, затраты на привлечения пользователей очень большие. Узнаем, в чём причина: в низкой конверсии или низком удержании.
#
# Посчитаем и визуализируем конверсию с разбивкой по странам, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# коверсия по странам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи США конвертируются значимо лучше других стран, причём постоянно. Видимо, дело в удержании. Вызовем функции `get_retention()` и `plot_retention()`, чтобы рассчитать и отразить на графиках удержание по устройствам.

# %%
# удержание по странам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Действительно, пользователи из США плохо удерживаются. Это видно на графике платящих пользователей. Если учитывать насколько выше у Сша конверсия по сравнению с другими странами, ударжание крайне низкое.
#
#
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам
#
# Рассчитаем и визуализируем LTV и ROI для всех пользователей, вызвав функции `get_ltv()` и `plot_ltv_roi()`, указав параметр страны для группировки - поле `channel`.

# %%
dimensions=['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days
)

# %% [markdown]
# Окупаемость у трех источников ниже 1: AdNonSense, FaceBoom и TipTop. У TipTop сильно растет график динамики стоимости привлечения пользователей. Посморим, может быть это связано с пользователями из США. Рассчитаем и визуализируем LTV и ROI для пользователей США аналогичным способом.

# %%
dimensions=['channel']
# срез пользователей США
profiles_us = profiles.query('region == "United States"')

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_us, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days
)

# %% [markdown]
# Действительно, рекламные каналы FaceBoom и TipTop не окупаются для пользователей США. Стоимость привлечения пользователей из TipTop огромная, при этом динамика LVT колеблется также как остальные. Это неоправдано высокие затраты на рекламу в TipTop. Но почему не окупается FaceBoom?
#
# Обозначим более узкую проблему - пользователи из США с рекламных каналов FaceBoom и TipTop не окупаются. Возьмем срез пользователей США `profiles_us` и посчитаем конверсию и удержание.
#
# Посчитаем и визуализируем конверсию с разбивкой по каналам, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# коверсия по каналам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_us, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсии для FaceBoom и TipTop наоборот выше остальных. Тогда проверим удержание пользователей, вызовем функции `get_retention()` и `plot_retention()`, чтобы рассчитать и отразить на графиках удержание по каналам привлечения.

# %%
# удержание по каналам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_us, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Показатели удержания у рекламного канала FaceBoom почти нулевые. Возможно, есть какая-то техническая ошибка, но ведь у других групп пользователей все исправно. Возможно, привлеченные пользователи с этого источника вообще не соответсвуют целевой аудитории приложения. Пользователи не возращаются в приложение. Нецелесообразно использовать этот источник трафика.
#
# ### Проверка гипотезы
#
# Проверим следующую гипотезу: Если исключить источники трафика FaceBoom и TipTop для пользователей США, то рекламная компания приложения Procrastinate Pro+ окупится.
#
# Для проверки создадим тестовую выборку пользователей `test_profiles`, в которую не будут входить данные о пользователях США с каналами привлечения FaceBoom и TipTop. Посмотрим на окупаемость рекламы по этим пользователям, для этого рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`.

# %%
# тестовая выборка без пользователей из США из рекламных каналов FaceBoom и TipTop
test_profiles = profiles.query('region == "United States" and channel not in ["FaceBoom", "TipTop"]')

# получение ltv и roi
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    test_profiles, orders, observation_date, horizon_days, dimensions=[], ignore_horizon=False
)
# визуализация данных
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Гипотеза оказалось верной! Без рекламных каналов FaceBoom и TipTop для пользователей США общая рекламная компания приложения прошла бы на ура. Если раньше ROI по итогам двух недель был чуть выше 0.8, то для текущей выборки показатель достиг 2.3, то есть реклама окупилась бы больше, чем в 2 раза.
#
# Посчитаем насколько много данных пользователей мы исключили:

# %%
print("Исключенная часть - {:.2%}".format(len(test_profiles) / len(profiles)))
# Out:
# Исключенная часть - 14.03%

# %% [markdown]
# ### Вывод
#
# Была проведена оценка окупаемости рекламы за период в 2 недели от 1 ноября 2019 года. Для анализа использованы графики LTV, ROI и CAC, также в случаях дополнительной проверки графики конверсии (RR) и ужержания (CR).
#
# Результаты оценки окупаемости рекламы:
# 1. Реклама, направленная на привлечение пользователей в целом не окупается;
# 2. Тип устройства не оказывает влияния на окупаемость;
# 3. Пользователи из США единственные не окупаются. Так как их значимая часть, это тянет всю рекламную компанию в убытки;
# 4. Именно рекламные каналы FaceBoom и TipTop для пользователей США не окупаются.
# 5. Стоимость привлечения пользователей из TipTop слишком велика, пользователи не приносят такого дохода, а пользователи FaceBoom не возвращаются в приложение после первого использования, показатели удержания близки к нулю.
# 6. Рекламная компания бы хорошо окупилась без рекламных каналов FaceBoom и TipTop для пользователей США. Если ROI по общим данным по итогам двух недель чуть выше 0.8, то для такой выборки показатель достиг 2.3, то есть реклама окупилась бы больше, чем в 2 раза.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Для анализа бизнес-показателей были загружены и использованы таблицы:
# * visits (лог сервера с информацией о посещениях сайта);
# * orders (информация о заказах);
# * costs(информация о затратах на маркетинг).
#
# В проект добавленны функции для создания профилей, расчёта удержания, конверсии, LTV и ROI из пройденных уроков курса: `get_profiles()`, `get_retention()`, `get_conversion()` и `get_ltv()`. А также функции для визуализации этих метрик — `filter_data()`, `plot_retention()`, `plot_conversion()` и `plot_ltv_roi()`.
#
# Были созданы профили пользователей и проведен иследовательский анализ данных по странам, устройства и рекламным каналам, в ходе которого было выяснено:
#
# - Пользователи приложения приходят из США, Великобритании, Франции и Германии. Платящих пользователей больше всеого из США, почти 7 тысяч, также и самый большой процент платящих от общего количества - 6,9%.
# - Пользователи пользуются устройствами iPhonе, Android, Mac и PC для посещения приложения. Самые популярные устройства - мобильные iPhonе и Android. При этом процент платящих пользователей самы высокий у Mac и iPhone.
# - У приложения 10 рекламных каналов продвижения, не считая органического. Наиболее эффективные их них органика, FaceBoom, затем TipTop. При этом процент платящих пользователей выше всего у FaceBoom, AdNonSense и lambdaMediaAds (больше 10%).
#
# В ходе анализа маркетинга был произведен расчет потраченных средств на рекламу. Всего потрачено `105497.3$`, больше всего средств совокупно ушло на TipTop и FaceBoom. Привлечение одного покупателя стоит в среднем `1.13$`. Также были произведены расчеты среднего CAC для каждого источника трафика. Самая большая стоимость привлечения пользователя у TipTop - `2.8$`, затем идут FaceBoom и AdNonSense со стоимостью чуть больше `1$`. При рассмотрениии CAC в динамике у канала TipTop средняя стоимость привлечения все время растет, с осени она выше `3.5$`, когда у остальных каналов она почти постоянна, колеблется в своих пределах.
#
# Была проведена оценка окупаемости рекламы за период в 2 недели от 1 ноября 2019 года. Для анализа использованы графики LTV, ROI и CAC, также в случаях дополнительной проверки графики конверсии (RR) и ужержания (CR).
#
# Результаты оценки окупаемости рекламы:
# * Реклама, направленная на привлечение пользователей в целом не окупается;
# * Тип устройства не оказывает влияния на окупаемость;
# * Пользователи из США единственные не окупаются. Так как их значимая часть, это тянет всю рекламную компанию в убытки;
# * Именно рекламные каналы FaceBoom и TipTop для пользователей США не окупаются.
#
# Стоимость привлечения пользователей из TipTop слишком велика, пользователи не приносят такого дохода, а пользователи FaceBoom не возвращаются в приложение после первого использования (удержание близко к нулю), возможно пользователи не соответвуют целевой аудитории приложения.
#
# Была подтверждена гипотеза о том, что если исключить источники трафика FaceBoom и TipTop для пользователей США, то рекламная компания приложения Procrastinate Pro+ окупится. Если ROI по итогам двух недель был чуть выше 0.8, то для данной выборки показатель достиг 2.3, то есть реклама окупилась бы больше, чем в 2 раза.
#
# В итогу проектной работы рекомендация для отдела маркетинга следущая: стоит исключить источники трафика FaceBoom и TipTop для пользователей США, обратить внимание на качество привлекаемых пользователей, они должны соответвовать ЦА.
